# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import sys
import os
import base64

# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
def read_dataset(file):
    df = pd.read_csv(file)
    return df

def get_data_info(df):
    bengin = df['verdict'].value_counts()[0]
    malicious = df['verdict'].value_counts()[1]
    total_record = df.shape[0]
    malicious_percentage = round((malicious/total_record)*100)
    benign_percentage = round((bengin/total_record)*100)
    print("Total Dataset Records--", total_record)
    print("Total Features---------", df.shape[1])
    print("Total Malicious Urls---", malicious)
    print("Total Benign Urls------", bengin)
    print("Malicious Percentage---", malicious_percentage)
    print("Benign Percentage------", benign_percentage)
    return True

def get_base64_decoded_string(base64_string):
    try:
        decoded_string = base64.b64decode(base64_string).decode('utf8')
        return decoded_string
    except Exception as e:
        print("Invalid Encoding:    %s" %e, "\n\nPlease provide base64 encoded string")

# %% [markdown]
# # Data Exploration

# %%
def get_attribute_effect_on_class(df, attribute_list=[]):
    df.groupby('verdict')[attribute_list].mean().plot(kind='bar')
    return True

def get_mean_values_for_all_features(df):
    print("\n\n*** Mean values of different attributes ***\n\n")
    return df.groupby('verdict').mean()

# %% [markdown]
# # Main Function

# %%
dataset_file = "/home/shahid/projects/behaviouralClassifier/classifier/urls_data_v2.csv"
df = read_dataset(dataset_file)
get_data_info(df)
get_mean_values_for_all_features(df)
# Out:
# Total Dataset Records-- 12589
# Total Features--------- 34
# Total Malicious Urls--- 470
# Total Benign Urls------ 12119
# Malicious Percentage--- 4.0
# Benign Percentage------ 96.0
#
#
# *** Mean values of different attributes ***
#            url_is_html  url_total_favicon  url_total_og_domains  \
# verdict
# Benign        0.976896           0.905520              4.511923
# Malicious     0.997872           0.580851              2.821277
#
#            url_total_og_links  domain_is_html  domain_total_favicon  \
# verdict
# Benign              48.069808        0.990841              0.953874
# Malicious           20.627660        1.000000              0.614894
#
#            domain_total_og_domains  domain_total_og_links  title_match  \
# verdict
# Benign                    5.007179              53.587342     0.823748
# Malicious                 3.365957              26.542553     0.823404
#
#            uri_length  url_length  domain_entropy  url_entropy  \
# verdict
# Benign       8.510686   38.093737        3.763092     3.947256
# Malicious   14.361702   44.480851        3.799228     4.073745
#
#            is_favicon_match  total_at_the_rate
# verdict
# Benign             0.933080           0.006024
# Malicious          0.912766           0.027660

# %%
# attribute plots
get_attribute_effect_on_class(df, ['domain_total_favicon','url_total_favicon'])
get_attribute_effect_on_class(df, ['domain_total_og_domains'])
get_attribute_effect_on_class(df, ['domain_entropy','url_entropy'])
get_attribute_effect_on_class(df, ['url_is_html','domain_is_html'])
get_attribute_effect_on_class(df, ['domain_total_og_links','url_total_og_links'])
get_attribute_effect_on_class(df, ['is_favicon_match'])
get_attribute_effect_on_class(df, ['uri_length', 'url_length'])
get_attribute_effect_on_class(df, ['title_match', 'is_favicon_match'])
# Out:
# True

# %%
X =  df[:-1]
Y =  df['verdict']

# %%
# Drop the unnecassary columns from the dataset
X_df = df.drop(['timestamp', 'url_md5', 'domain_md5', 'verdict_update_timestamp', 'landing_url_hash'], axis=1)
X_df.head()
# Out:
#                                           url_base64  \
# 0  aHR0cDovL3dzb3dlYi5sYWR3cC5jb20vQXF1ZWR1Y3QvaW...
# 1  aHR0cHM6Ly93d3cudmNkZWxpdmVyeS5jb20vQ2VydC9nYy...
# 2  aHR0cDovL2NkbnNzbC5jbGlja3RhbGUubmV0L3d3dy9wdG...
# 3                           aHR0cDovL3Roem9tLmNvbS8=
# 4           aHR0cDovL3N1cnlhbG9nYW1wZXJrYXNhLmNvbS8=
#
#                                            url_title  \
# 0                 404 - File or directory not found.
# 1                                  Certificate Error
# 2                 404 - File or directory not found.
# 3                                      贵州易一点信息技术有限公司
# 4  CV SURYA LOGAM PERKAS – Melayani segala pembua...
#
#                        url_favicons  url_is_html          url_content_type  \
# 0                               NaN         True                 text/html
# 1                               NaN         True  text/html; charset=utf-8
# 2                               NaN         True                 text/html
# 3  2b9e04f90cde9e41729a54aacd18f82c         True   text/html;charset=utf-8
# 4                               NaN         True  text/html; charset=UTF-8
#
#    url_total_favicon                                     url_og_domains  \
# 0                  0                                                NaN
# 1                  0                   5f395d3a47e44537ade5365501edc4d1
# 2                  0                                                NaN
# 3                  1  5714ef957868fa31c71ff7779a180abc,693bb6289543b...
# 4                  0  bd6da7ce0c96549c993375c2f1a0da28,d40211678368f...
#
#    url_total_og_domains  url_total_og_links url_file_type   ...    \
# 0                     0                   0            -1   ...
# 1                     1                   1     text/html   ...
# 2                     0                   0            -1   ...
# 3                    12                  57     text/html   ...
# 4                     4                  18     text/html   ...
#
#   domain_file_type                                 landing_url_base64  \
# 0               -1  aHR0cDovL3dzb3dlYi5sYWR3cC5jb20vQXF1ZWR1Y3QvaW...
# 1        text/html  aHR0cHM6Ly93d3cudmNkZWxpdmVyeS5jb20vQ2VydC9nYy...
# 2        text/html  aHR0cDovL2NkbnNzbC5jbGlja3RhbGUubmV0L3d3dy9wdG...
# 3        text/html                   aHR0cDovL3d3dy5nenl5ZGl0LmNvbS8=
# 4        text/html       aHR0cDovL3d3dy5zdXJ5YWxvZ2FtcGVya2FzYS5jb20v
#
#   title_match  uri_length url_length  domain_entropy url_entropy  \
# 0       False          35         58        3.855389    4.451966
# 1       False          13        110        4.032303    5.335842
# 2       False          49         76        3.726474    4.556881
# 3        True           1         17        3.175123    3.175123
# 4        True           1         29        4.004364    4.004364
#
#    is_favicon_match  total_at_the_rate verdict
# 0                 1                  0  Benign
# 1                 1                  0  Benign
# 2                 0                  0  Benign
# 3                 1                  0  Benign
# 4                 1                  0  Benign
#
# [5 rows x 29 columns]

# %%
print("\nTotal useful attributes:  ", len(X_df.columns.tolist()),"\n")
# Out:
# Total useful attributes:   29

# %%
X_df2 = X_df
X_df2
# Out:
#                                               url_base64  \
# 0      aHR0cDovL3dzb3dlYi5sYWR3cC5jb20vQXF1ZWR1Y3QvaW...
# 1      aHR0cHM6Ly93d3cudmNkZWxpdmVyeS5jb20vQ2VydC9nYy...
# 2      aHR0cDovL2NkbnNzbC5jbGlja3RhbGUubmV0L3d3dy9wdG...
# 3                               aHR0cDovL3Roem9tLmNvbS8=
# 4               aHR0cDovL3N1cnlhbG9nYW1wZXJrYXNhLmNvbS8=
# 5                           aHR0cDovL2FsYnJpZGdlLmNvbS8=
# 6                   aHR0cDovL3d3dy5yZWZpbml0aXYuY29tLw==
# 7                           aHR0cDovLzIxNi41OC4xOTkuMS8=
# 8                           aHR0cDovL3NjaG9vbDRrLmNvbS8=
# 9               aHR0cDovL2NpYnJpYW5jb250cmFjdG9ycy5jb20v
# 10                  aHR0cDovL3N1cG9ydGUtY29udGF0by5jb20v
# 11     aHR0cDovL2wuYmV0cmFkLmNvbS9jdC8wXzBfMjA2ODgzNj...
# 12                          aHR0cDovL3NpZ2hiZWFyLmNvbS8=
# 13     aHR0cDovL3NreWNueHoyLnd5MTE5LmNvbS8yL2p4d3pnal...
# 14          aHR0cDovL3d3dy53b3JsZHRyYXZlbGd1aWRlLm5ldC8=
# 15      aHR0cDovL2tvcm9zc3VyZ2ljYWxpbnN0cnVtZW50cy5jb20v
# 16     aHR0cDovL2FwcC5saW5rLnBlbnRvbmZvb2RuZXdzLmNvbS...
# 17                          aHR0cDovL3dlYXRoZXIuZ2MuY2Ev
# 18                      aHR0cDovL2Fpcm1lZHRlYXIubmV0Lw==
# 19                          aHR0cDovLzE3Mi4yMTcuOC4xMzIv
# 20                          aHR0cDovL2p5dGlsZXMuY29tLw==
# 21      aHR0cHM6Ly9kdGFjb25uZWN0LmVvaGhzLm1hc3MuZ292Lw==
# 22                              aHR0cDovL3F5amR0LmNvbS8=
# 23                      aHR0cDovL2R1dGkud3BvZGZzai50dy8=
# 24                      aHR0cDovL2JpYmxlY3JhY2suY29tLw==
# 25                          aHR0cDovL2h0eWlzaGFuZy5jb20v
# 26     aHR0cHM6Ly93d3cueG4tLXZpYWplcm9zdWVvcy1qaGIuY2...
# 27                  aHR0cDovL3d3dy5hbmVrYXNhcmkuY29tLw==
# 28     aHR0cDovL2J5dGVpbmZvc3lzLmNvbS9wdWJsaWNfbGlicm...
# 29     aHR0cHM6Ly9jdXMuYmVjdHJhbi5jb20vY3VzdG9tZXIvRV...
# ...                                                  ...
# 12559                       aHR0cDovL29wZW4tc2V6Lm1lLw==
# 12560               aHR0cDovL21ha2lueW91Ymx1c2guY29tLw==
# 12561       aHR0cHM6Ly93d3cua29uYWNvYXN0d2luZG93cy5jb20v
# 12562                           aHR0cHM6Ly9hc3NvdWsubWEv
# 12563                   aHR0cHM6Ly9jZWFjLnN0YXRlLmdvdi8=
# 12564  aHR0cDovL2hvbGdlcm9iZW5hdXMuY29tL3JQYlMtSkd3eH...
# 12565                       aHR0cDovL3NhdHVtYXIub3JnLw==
# 12566  aHR0cDovL2tpZW1iYWMudm4vcmFvdmF0LzEyOTgvMjU3Mj...
# 12567                           aHR0cDovLzRlZGEuY29tLw==
# 12568  aHR0cHM6Ly93d3cudG9ybG9jay5jb20vdG9ycmVudC83OD...
# 12569               aHR0cDovL215c3RpY3JlYWxwb2xsLmNvbS8=
# 12570                       aHR0cDovL2R2dGFzYXJpLmNvbS8=
# 12571                   aHR0cDovL3Nib21hZ2F6aW5lLmNvbS8=
# 12572               aHR0cDovLzIxOC4xNDUuMjYuNzUvbnNwLw==
# 12573                           aHR0cDovL3NzMTEzMC5jb20v
# 12574                           aHR0cDovL2x5aGVwLm9yZy8=
# 12575                           aHR0cDovL3RpaW1vLm5ldC8=
# 12576                   aHR0cDovL2lyYW5zb3VyY2VzLm5ldC8=
# 12577  aHR0cDovL2pzLXJlYWN0LmNvbS9nYXRlLnBocD90b2tlbj...
# 12578                       aHR0cDovL3d3dy5uYWljLm9yZy8=
# 12579                   aHR0cHM6Ly9zMjk4Mi5wY2RuLmNvLw==
# 12580                   aHR0cDovL25vdGVmbGdpaHQuY29tLw==
# 12581                   aHR0cDovL3dvbGplb25nc2EubmV0Lw==
# 12582               aHR0cDovL3BsaW50YWtpZHMuY29tL3dlRlQv
# 12583   aHR0cHM6Ly9kb21hbmVvcmEuZmlyZWJhc2VhcHAuY29tLw==
# 12584               aHR0cDovL2UtYmFsYW5jZS1saWZlLmNvbS8=
# 12585                       aHR0cDovL2Frc3FpcGFpLmNvbS8=
# 12586                       aHR0cDovL2RheGluYm9saS5jb20v
# 12587                       aHR0cDovL21vb2R5ZmFzaC5jb20v
# 12588  aHR0cHM6Ly94bi0tZ3ZlbmxpaGlwZXJtYXJrZXQtMjJiLm...
#
#                                                url_title  \
# 0                     404 - File or directory not found.
# 1                                      Certificate Error
# 2                     404 - File or directory not found.
# 3                                          贵州易一点信息技术有限公司
# 4      CV SURYA LOGAM PERKAS – Melayani segala pembua...
# 5      Albridge - Data Aggregation and Consolidated W...
# 6      Financial Technology, Data, and Expertise | Re...
# 7                                                 Google
# 8                                           school4k.com
# 9                  Cibrian Contractors - Port Arthur, TX
# 10     Aromaterapia de verão para mamães, bebê e família
# 11                                                   NaN
# 12                            home warranty utah reviews
# 13                                        404页面未找到_爱天空下载
# 14     World Travel Guide | Official Destination Guid...
# 15                                                   NaN
# 16     Butterscotch Pudding Shots made with OREO Cook...
# 17              Weather Information - Environment Canada
# 18                                           1&1 Hosting
# 19                                                Google
# 20                                                炸金花提现金
# 21     DTA Connect - Massachusetts Department of Tran...
# 22                                                   NaN
# 23                                   LNMP一键安装包 by Licess
# 24                                                   NaN
# 25                                        北京易尚国际建筑装饰有限公司
# 26     ViajeroSue?os - Viajes, Blog De Viajes, Vacaci...
# 27     Aneka Sari Restoran Paket Pernikahan, Ruang Pe...
# 28                          404 Not Found | Byte Infosys
# 29                                                   NaN
# ...                                                  ...
# 12559           5919 Default Passwords from Open Sez Me!
# 12560                                           Younique
# 12561            Kona Coast Professional Window Cleaning
# 12562                                         Index of /
# 12563                                                NaN
# 12564  Holger Obenaus Photography LLC | Commercial Ph...
# 12565                                        satumar.org
# 12566  Dự án đất nền Long Thành nổi bật nhất hiện nay do
# 12567              大香蕉视频在线播放2018_大香蕉97超级碰碰视频_大香蕉免费视频在线播放
# 12568                       Torlock - 404 Page not Found
# 12569                                          Ana Sayfa
# 12570                       dvtasari.com – Personal Blog
# 12571                                         News - SBO
# 12572                                                NaN
# 12573                                               食色精选
# 12574                     良い袴レンタル業者なら前撮りからヘアメイクまで一括依頼が可能
# 12575                           tiimo.net is coming soon
# 12576                                    iransources.net
# 12577                                                NaN
# 12578    National Association of Insurance Commissioners
# 12579                                   Home | BOOK RIOT
# 12580                                     noteflgiht.com
# 12581                                            오대산클라우드
# 12582                                     Index of /weFT
# 12583               Infos couverture mobile - Assistance
# 12584                                      e-Balance株式会社
# 12585                                              008彩票
# 12586                                       广州大鑫玻璃实业有限公司
# 12587  moody fash and purpose | camisas oversized, ki...
# 12588                             Güvenli Hipermarketler
#
#                                             url_favicons  url_is_html  \
# 0                                                    NaN         True
# 1                                                    NaN         True
# 2                                                    NaN         True
# 3                       2b9e04f90cde9e41729a54aacd18f82c         True
# 4                                                    NaN         True
# 5      e9783a9b9574e23aaa6de63168272b6b,d41d8cd98f00b...         True
# 6                                                    NaN         True
# 7                                                    NaN         True
# 8                                                    NaN         True
# 9                       adfed9a7cc876e19b3e8f27f28e19ef2         True
# 10     d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 11                                                   NaN         True
# 12                                                   NaN         True
# 13                                                   NaN         True
# 14                      d41d8cd98f00b204e9800998ecf8427e         True
# 15                                                   NaN         True
# 16                                                   NaN         True
# 17     d41d8cd98f00b204e9800998ecf8427e,ee9d6637513c5...         True
# 18                      d41d8cd98f00b204e9800998ecf8427e         True
# 19                                                   NaN         True
# 20                                                   NaN         True
# 21                      9c46e26ad0be45666b4ebe43e67d15b0         True
# 22                                                   NaN         True
# 23                                                   NaN         True
# 24     2986f7db75e3f03794c85ee38aa9c7b9,d41d8cd98f00b...         True
# 25                                                   NaN         True
# 26     d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 27     3be62928e184dd5e25ba091a6f51e392,3be62928e184d...         True
# 28                      c947c8255e26d2cb324b02ce60134650         True
# 29     d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# ...                                                  ...          ...
# 12559                                                NaN         True
# 12560  d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 12561                   7d856b0a0d218f039a5aaab53b5e73e3         True
# 12562                                                NaN         True
# 12563                                                NaN         True
# 12564                   d41d8cd98f00b204e9800998ecf8427e         True
# 12565                                                NaN         True
# 12566                                                NaN         True
# 12567                                                NaN         True
# 12568  d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 12569                   d41d8cd98f00b204e9800998ecf8427e         True
# 12570  d41d8cd98f00b204e9800998ecf8427e,36b6dc881d0ef...         True
# 12571                   d405c95289434bd6c1299933ac436ff8         True
# 12572                                                NaN         True
# 12573                   adfd8c358e0335b11360d5d9491f9811         True
# 12574                                                NaN         True
# 12575                                                NaN         True
# 12576                                                NaN         True
# 12577                                                NaN         True
# 12578  d41d8cd98f00b204e9800998ecf8427e,bda87414f99a1...         True
# 12579                                                NaN         True
# 12580                                                NaN         True
# 12581                                                NaN         True
# 12582                                                NaN         True
# 12583                                                NaN         True
# 12584                   d41d8cd98f00b204e9800998ecf8427e         True
# 12585                                                NaN         True
# 12586                                                NaN         True
# 12587  d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 12588                   ad9989c13d8b8748cc8facfd0a3fcd84         True
#
#                    url_content_type  url_total_favicon  \
# 0                         text/html                  0
# 1          text/html; charset=utf-8                  0
# 2                         text/html                  0
# 3           text/html;charset=utf-8                  1
# 4          text/html; charset=UTF-8                  0
# 5           text/html;charset=utf-8                 14
# 6          text/html; charset=UTF-8                  0
# 7          text/html; charset=UTF-8                  0
# 8          text/html; charset=utf-8                  0
# 9          text/html; charset=utf-8                  1
# 10          text/html;charset=utf-8                  2
# 11        text/plain; charset=utf-8                  0
# 12                        text/html                  0
# 13                        text/html                  0
# 14         text/html; charset=UTF-8                  1
# 15                        text/html                  0
# 16                        text/html                  0
# 17                        text/html                  2
# 18                        text/html                  1
# 19         text/html; charset=UTF-8                  0
# 20                        text/html                  0
# 21         text/html; charset=UTF-8                  1
# 22         text/html; charset=utf-8                  0
# 23                        text/html                  0
# 24                        text/html                  3
# 25         text/html; charset=UTF-8                  0
# 26          text/html;charset=utf-8                  9
# 27          text/html;charset=UTF-8                  2
# 28         text/html; charset=UTF-8                  1
# 29          text/html;charset=utf-8                  2
# ...                             ...                ...
# 12559                     text/html                  0
# 12560      text/html; charset=utf-8                  2
# 12561      text/html; charset=UTF-8                  1
# 12562  text/html;charset=ISO-8859-1                  0
# 12563                     text/html                  0
# 12564      text/html; charset=UTF-8                  1
# 12565      text/html; charset=UTF-8                  0
# 12566      text/html; charset=utf-8                  0
# 12567      text/html; charset=utf-8                  0
# 12568      text/html; charset=UTF-8                  3
# 12569      text/html; charset=utf-8                  1
# 12570      text/html; charset=UTF-8                  3
# 12571      text/html; charset=utf-8                  1
# 12572     text/plain; charset=utf-8                  0
# 12573                     text/html                  1
# 12574                     text/html                  0
# 12575      text/html; charset=utf-8                  0
# 12576      text/html; charset=utf-8                  0
# 12577      text/html; charset=UTF-8                  0
# 12578      text/html; charset=UTF-8                  9
# 12579      text/html; charset=UTF-8                  0
# 12580                     text/html                  0
# 12581      text/html; charset=utf-8                  0
# 12582  text/html;charset=ISO-8859-1                  0
# 12583      text/html; charset=utf-8                  0
# 12584      text/html; charset=UTF-8                  1
# 12585                     text/html                  0
# 12586      text/html; charset=utf-8                  0
# 12587       text/html;charset=utf-8                  2
# 12588      text/html; charset=utf-8                  1
#
#                                           url_og_domains  \
# 0                                                    NaN
# 1                       5f395d3a47e44537ade5365501edc4d1
# 2                                                    NaN
# 3      5714ef957868fa31c71ff7779a180abc,693bb6289543b...
# 4      bd6da7ce0c96549c993375c2f1a0da28,d40211678368f...
# 5      534cbaa1a9eab6780ed10d7287219486,e203e98e4c606...
# 6      bcbafb69b52516b1733a52b737d2d4b7,4fd9c9a2de4fb...
# 7      e0b106fd149f84e5156335d2d9c0d3cb,ff31304115d63...
# 8      9f7ca836a72f4d4e60bc770d4fa385e2,693bb6289543b...
# 9      e83444f932f78fae7d28e39eb685bbc7,202931abfb5c0...
# 10     bcbafb69b52516b1733a52b737d2d4b7,e203e98e4c606...
# 11                                                   NaN
# 12     a76c9094c2b0665e23d7154e6358023e,1af54cfb0dd3a...
# 13     47b045611d775923fb0fd28cf871d58b,89450250028cd...
# 14     4fd9c9a2de4fbab8494b2f27d37f3118,7c1cf5c9418c7...
# 15                                                   NaN
# 16     4b6f3c453452886757ecad254783a851,693bb6289543b...
# 17     cc2caadef6fe5316369933873c6bf8db,b327b3397a5b3...
# 18     2417d399bb6c54a61f86cdf817297dab,0dccc671aacce...
# 19     e0b106fd149f84e5156335d2d9c0d3cb,ff31304115d63...
# 20     693bb6289543b15968e0589ca251fe02,b859d6419a038...
# 21     4fd9c9a2de4fbab8494b2f27d37f3118,4bb8a59adaa41...
# 22                      f72fff639c1ed0bec9fe77632c1ce9fb
# 23     3d27ac976958de55dab25171138bb73d,33c77a86deea8...
# 24     5f395d3a47e44537ade5365501edc4d1,007e43e87235e...
# 25     693bb6289543b15968e0589ca251fe02,f765d6f8d5c87...
# 26     bcbafb69b52516b1733a52b737d2d4b7,693bb6289543b...
# 27     4fd9c9a2de4fbab8494b2f27d37f3118,e203e98e4c606...
# 28     3b774b7e253e5a8691a5f0ccfecf1cbc,d789518199713...
# 29     7551b8c65d3d53eeb51bf564f939df12,849cd43e9d2ff...
# ...                                                  ...
# 12559  ff7e483f6cb1f3399e08e6280eef72a4,5f395d3a47e44...
# 12560  576459b854f2866b17c553438fe67f26,4bb8a59adaa41...
# 12561  ff841c564704e45480b6be974cb669b0,b698c95a75249...
# 12562                   ff84de2ba015298fddd9bfd8b68ee5da
# 12563                                                NaN
# 12564  4fd9c9a2de4fbab8494b2f27d37f3118,e203e98e4c606...
# 12565  1faa9e5275e997bf5172bb4c1623325a,b54146c71d930...
# 12566  fe3e5aa3d37269aec79457333dfcaf5a,45e38578e90f4...
# 12567  1ac7e0ff111bef43a6e1737a23a09eb3,a972b93b2130b...
# 12568  cfedee72653b0a3004cd19fbd45fe766,9a5ea28899ee6...
# 12569  87468c07c02e370ef84d4b7e3a668589,ffa59042ef1a3...
# 12570  bcbafb69b52516b1733a52b737d2d4b7,ffa75f2424db9...
# 12571  87468c07c02e370ef84d4b7e3a668589,f6eb9965c04f8...
# 12572                                                NaN
# 12573                   ffb3daf078b26d6766cf934d8426d354
# 12574  7009109390ebafbcc02c4cf953f19556,eb36d832b5e7b...
# 12575  b82ef12cfe38fadbd40aefc517aae728,1270184e3b81d...
# 12576  a6edffed76f9d480c5e885a61eeca94e,693bb6289543b...
# 12577                                                NaN
# 12578  976555ae62ef06c0096177fe7fd196ed,ad490297a5c17...
# 12579  9fc4962e6a0c531db598343aa72216de,157a54f2ab805...
# 12580                   693bb6289543b15968e0589ca251fe02
# 12581  b538729e4c867856e3cbee40e7d04994,f344cf7cb73d6...
# 12582                   868bac9ba1f6721712315a1b62d5bf58
# 12583                   d41d8cd98f00b204e9800998ecf8427e
# 12584                   ffe2a4523147742c561abfd06d90cb5b
# 12585  c7d06a5e4c1ed600e55306a8b5bc2b2a,693bb6289543b...
# 12586  693bb6289543b15968e0589ca251fe02,ffec5245f70c8...
# 12587  bcbafb69b52516b1733a52b737d2d4b7,04aa94e8a455e...
# 12588  bcbafb69b52516b1733a52b737d2d4b7,4fd9c9a2de4fb...
#
#        url_total_og_domains  url_total_og_links    url_file_type    ...      \
# 0                         0                   0               -1    ...
# 1                         1                   1        text/html    ...
# 2                         0                   0               -1    ...
# 3                        12                  57        text/html    ...
# 4                         4                  18        text/html    ...
# 5                        13                  60        text/html    ...
# 6                        14                 261        text/html    ...
# 7                        21                  42        text/html    ...
# 8                         3                   3        text/html    ...
# 9                         4                  29        text/html    ...
# 10                       10                  39        text/html    ...
# 11                        0                   0               -1    ...
# 12                        5                  19        text/html    ...
# 13                        2                   2               -1    ...
# 14                       11                  98        text/html    ...
# 15                        0                   0        text/html    ...
# 16                       15                 140        text/html    ...
# 17                       30                 314        text/html    ...
# 18                        2                  11        text/html    ...
# 19                       21                  42        text/html    ...
# 20                        3                  54        text/html    ...
# 21                        7                  15        text/html    ...
# 22                        1                   1        text/html    ...
# 23                        5                  11        text/html    ...
# 24                        6                   9       text/plain    ...
# 25                        7                  53        text/html    ...
# 26                        4                  54        text/html    ...
# 27                       12                 162        text/html    ...
# 28                        5                  22               -1    ...
# 29                        2                   5  application/xml    ...
# ...                     ...                 ...              ...    ...
# 12559                     3                 783        text/html    ...
# 12560                     6                 169        text/html    ...
# 12561                     2                  18        text/html    ...
# 12562                     1                   5        text/html    ...
# 12563                     0                   0             None    ...
# 12564                     7                  89        text/html    ...
# 12565                    12                 256        text/html    ...
# 12566                    20                 187        text/html    ...
# 12567                    14                 119        text/html    ...
# 12568                    12                  35               -1    ...
# 12569                     6                  16        text/html    ...
# 12570                     7                  15        text/html    ...
# 12571                    19                 171        text/html    ...
# 12572                     0                   0    inode/x-empty    ...
# 12573                     1                   2        text/html    ...
# 12574                     2                  14        text/html    ...
# 12575                     5                  14        text/html    ...
# 12576                     3                   3        text/html    ...
# 12577                     0                   0       text/plain    ...
# 12578                    29                 324        text/html    ...
# 12579                    17                 153        text/html    ...
# 12580                     1                   1        text/html    ...
# 12581                    15                  92        text/html    ...
# 12582                     1                   3        text/html    ...
# 12583                     1                  57        text/html    ...
# 12584                     1                  12       text/plain    ...
# 12585                     2                  10        text/html    ...
# 12586                     6                 136        text/html    ...
# 12587                     4                  13        text/html    ...
# 12588                     9                  94        text/html    ...
#
#       domain_file_type                                 landing_url_base64  \
# 0                   -1  aHR0cDovL3dzb3dlYi5sYWR3cC5jb20vQXF1ZWR1Y3QvaW...
# 1            text/html  aHR0cHM6Ly93d3cudmNkZWxpdmVyeS5jb20vQ2VydC9nYy...
# 2            text/html  aHR0cDovL2NkbnNzbC5jbGlja3RhbGUubmV0L3d3dy9wdG...
# 3            text/html                   aHR0cDovL3d3dy5nenl5ZGl0LmNvbS8=
# 4            text/html       aHR0cDovL3d3dy5zdXJ5YWxvZ2FtcGVya2FzYS5jb20v
# 5            text/html               aHR0cHM6Ly93d3cuYWxicmlkZ2UuY29tLw==
# 6            text/html           aHR0cHM6Ly93d3cucmVmaW5pdGl2LmNvbS9lbg==
# 7            text/html   aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8/Z3dzX3JkPXNzbA==
# 8            text/html                   aHR0cDovL3d3dy5zY2hvb2w0ay5jb20v
# 9            text/html           aHR0cDovL2NpYnJpYW5jb250cmFjdG9ycy5jb20v
# 10           text/html       aHR0cHM6Ly93d3cuc3Vwb3J0ZS1jb250YXRvLmNvbS8=
# 11                  -1                                           ZGF0YTos
# 12           text/html                       aHR0cDovL3NpZ2hiZWFyLmNvbS8=
# 13                  -1  aHR0cDovL3NreWNueHoyLnd5MTE5LmNvbS8yL2p4d3pnal...
# 14           text/html       aHR0cHM6Ly93d3cud29ybGR0cmF2ZWxndWlkZS5uZXQv
# 15           text/html   aHR0cDovL2tvcm9zc3VyZ2ljYWxpbnN0cnVtZW50cy5jb20v
# 16           text/html  aHR0cHM6Ly93d3cuZm9vZHNlcnZpY2Utc25hY2tzLWRlc3...
# 17           text/html                   aHR0cHM6Ly93ZWF0aGVyLmdjLmNhLw==
# 18           text/html       aHR0cDovL2Fpcm1lZHRlYXIubmV0L2RlZmF1bHRzaXRl
# 19           text/html   aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8/Z3dzX3JkPXNzbA==
# 20           text/html                       aHR0cHM6Ly9qeXRpbGVzLmNvbS8=
# 21           text/html   aHR0cHM6Ly9kdGFjb25uZWN0LmVvaGhzLm1hc3MuZ292Lw==
# 22           text/html                           aHR0cDovL3F5amR0LmNvbS8=
# 23           text/html                   aHR0cDovL2R1dGkud3BvZGZzai50dy8=
# 24          text/plain                   aHR0cDovL2JpYmxlY3JhY2suY29tLw==
# 25           text/html                       aHR0cDovL2h0eWlzaGFuZy5jb20v
# 26           text/html       aHR0cHM6Ly94bi0tdmlhamVyb3N1ZW9zLWpoYi5jb20v
# 27           text/html               aHR0cHM6Ly93d3cuYW5la2FzYXJpLmNvbS8=
# 28           text/html  aHR0cDovL3d3dy5ieXRlaW5mb3N5cy5jb20vcHVibGljX2...
# 29                  -1  aHR0cHM6Ly9jdXMuYmVjdHJhbi5jb20vY3VzdG9tZXIvZ2...
# ...                ...                                                ...
# 12559        text/html                       aHR0cDovL29wZW4tc2V6Lm1lLw==
# 12560        text/html  aHR0cHM6Ly93d3cueW91bmlxdWVwcm9kdWN0cy5jb20vS3...
# 12561        text/html       aHR0cHM6Ly93d3cua29uYWNvYXN0d2luZG93cy5jb20v
# 12562        text/html                           aHR0cHM6Ly9hc3NvdWsubWEv
# 12563             None                   aHR0cHM6Ly9jZWFjLnN0YXRlLmdvdi8=
# 12564        text/html           aHR0cHM6Ly93d3cuaG9sZ2Vyb2JlbmF1cy5jb20v
# 12565        text/html                       aHR0cDovL3NhdHVtYXIub3JnLw==
# 12566        text/html  aHR0cDovL2tpZW1iYWMudm4vcmFvdmF0LzEyOTgvMjU3Mj...
# 12567        text/html                           aHR0cDovLzRlZGEuY29tLw==
# 12568        text/html  aHR0cHM6Ly93d3cudG9ybG9jay5jb20vdG9ycmVudC83OD...
# 12569        text/html               aHR0cDovL215c3RpY3JlYWxwb2xsLmNvbS8=
# 12570        text/html                       aHR0cDovL2R2dGFzYXJpLmNvbS8=
# 12571        text/html                   aHR0cDovL3Nib21hZ2F6aW5lLmNvbS8=
# 12572    inode/x-empty               aHR0cDovLzIxOC4xNDUuMjYuNzUvbnNwLw==
# 12573        text/html                           aHR0cDovL3NzMTEzMC5jb20v
# 12574        text/html                       aHR0cDovL3d3dy5seWhlcC5vcmcv
# 12575        text/html                           aHR0cDovL3RpaW1vLm5ldC8=
# 12576        text/html               aHR0cDovL3d3dy5pcmFuc291cmNlcy5uZXQv
# 12577  application/xml  aHR0cDovL2pzLXJlYWN0LmNvbS9nYXRlLnBocD90b2tlbj...
# 12578        text/html                       aHR0cHM6Ly93d3cubmFpYy5vcmcv
# 12579        text/html               aHR0cHM6Ly93d3cuYm9va3Jpb3QuY29tLw==
# 12580        text/html  aHR0cDovL3d3My5ub3RlZmxnaWh0LmNvbS8/c3ViaWQxPT...
# 12581        text/html                   aHR0cDovL3dvbGplb25nc2EubmV0Lw==
# 12582        text/html               aHR0cDovL3BsaW50YWtpZHMuY29tL3dlRlQv
# 12583        text/html   aHR0cHM6Ly9kb21hbmVvcmEuZmlyZWJhc2VhcHAuY29tLw==
# 12584       text/plain               aHR0cDovL2UtYmFsYW5jZS1saWZlLmNvbS8=
# 12585        text/html  aHR0cHM6Ly93d3cuODYwMDguY29tL2hvbWUvcmVnLmh0bW...
# 12586        text/html                       aHR0cDovL2RheGluYm9saS5jb20v
# 12587        text/html               aHR0cHM6Ly93d3cubW9vZHlmYXNoLmNvbS8=
# 12588        text/html  aHR0cHM6Ly94bi0tZ3ZlbmxpaGlwZXJtYXJrZXQtMjJiLm...
#
#       title_match  uri_length url_length  domain_entropy url_entropy  \
# 0           False          35         58        3.855389    4.451966
# 1           False          13        110        4.032303    5.335842
# 2           False          49         76        3.726474    4.556881
# 3            True           1         17        3.175123    3.175123
# 4            True           1         29        4.004364    4.004364
# 5            True           1         20        3.984184    3.984184
# 6            True           1         25        3.803074    3.803074
# 7            True           1         20        3.408695    3.408695
# 8            True           1         20        3.546439    3.546439
# 9            True           1         30        3.698069    3.698069
# 10           True           1         27        3.704349    3.704349
# 11           True          66        134        3.746439    4.734834
# 12           True           1         20        3.884184    3.884184
# 13           True          17         42        4.132944    4.460903
# 14           True           1         32        3.952820    3.952820
# 15           True           1         36        4.051462    4.051462
# 16          False           5        166        3.978864    4.888872
# 17           True           1         21        3.463281    3.463281
# 18           True           1         22        3.481715    3.481715
# 19           True           1         21        3.296148    3.296148
# 20           True           1         19        3.747413    3.747413
# 21           True           1         34        3.822182    3.822182
# 22           True           1         17        3.528064    3.528064
# 23           True           1         23        3.621176    3.621176
# 24           True           1         22        3.845351    3.845351
# 25           True           1         21        3.713048    3.713048
# 26           True           1         37        4.296631    4.296631
# 27           True           1         25        3.913270    3.913270
# 28          False          23         45        3.849224    4.277871
# 29           True          18        115        3.823935    5.518164
# ...           ...         ...        ...             ...         ...
# 12559        True           1         19        3.536887    3.536887
# 12560        True           1         25        4.053661    4.053661
# 12561        True           1         33        3.775476    3.775476
# 12562        True           1         18        3.419382    3.419382
# 12563        True           1         23        3.534219    3.534219
# 12564        True          56         80        4.023465    5.158695
# 12565        True           1         19        3.536887    3.536887
# 12566       False          75         92        3.794653    4.349832
# 12567        True           1         16        3.577820    3.577820
# 12568       False          56         79        3.625815    4.596264
# 12569        True           1         26        3.844107    3.844107
# 12570        True           1         20        3.746439    3.746439
# 12571        True           1         23        3.969002    3.969002
# 12572        True           5         25        3.558519    3.733661
# 12573        True           1         18        3.572431    3.572431
# 12574        True           1         17        3.454822    3.454822
# 12575        True           1         17        3.219528    3.219528
# 12576        True           1         23        3.762267    3.762267
# 12577       False           9         51        3.746439    4.485576
# 12578        True           1         20        3.646439    3.646439
# 12579        True           1         22        3.697846    3.697846
# 12580        True           1         22        3.697846    3.697846
# 12581        True           1         22        3.754442    3.754442
# 12582       False           6         27        3.845351    4.134336
# 12583        True           1         34        3.998653    3.998653
# 12584        True           1         26        3.950064    3.950064
# 12585        True           1         20        3.684184    3.684184
# 12586        True           1         21        3.880180    3.880180
# 12587        True           1         21        3.653757    3.653757
# 12588        True           1         38        4.378992    4.378992
#
#        is_favicon_match  total_at_the_rate    verdict
# 0                     1                  0     Benign
# 1                     1                  0     Benign
# 2                     0                  0     Benign
# 3                     1                  0     Benign
# 4                     1                  0     Benign
# 5                     1                  0     Benign
# 6                     1                  0     Benign
# 7                     1                  0     Benign
# 8                     1                  0     Benign
# 9                     1                  0     Benign
# 10                    1                  0     Benign
# 11                    1                  0     Benign
# 12                    1                  0     Benign
# 13                    1                  0     Benign
# 14                    1                  0     Benign
# 15                    1                  0     Benign
# 16                    1                  0     Benign
# 17                    1                  0     Benign
# 18                    1                  0     Benign
# 19                    1                  0     Benign
# 20                    1                  0     Benign
# 21                    1                  0     Benign
# 22                    1                  0     Benign
# 23                    1                  0     Benign
# 24                    1                  0     Benign
# 25                    1                  0     Benign
# 26                    1                  0     Benign
# 27                    1                  0     Benign
# 28                    1                  0     Benign
# 29                    0                  0     Benign
# ...                 ...                ...        ...
# 12559                 1                  0     Benign
# 12560                 1                  0     Benign
# 12561                 1                  0     Benign
# 12562                 1                  0     Benign
# 12563                 1                  0     Benign
# 12564                 1                  0     Benign
# 12565                 1                  0     Benign
# 12566                 1                  0     Benign
# 12567                 1                  0     Benign
# 12568                 1                  0     Benign
# 12569                 1                  0     Benign
# 12570                 1                  0     Benign
# 12571                 1                  0     Benign
# 12572                 1                  0     Benign
# 12573                 1                  0     Benign
# 12574                 1                  0     Benign
# 12575                 1                  0     Benign
# 12576                 1                  0     Benign
# 12577                 0                  0     Benign
# 12578                 1                  0     Benign
# 12579                 1                  0     Benign
# 12580                 1                  0     Benign
# 12581                 1                  0     Benign
# 12582                 0                  0  Malicious
# 12583                 1                  0     Benign
# 12584                 1                  0     Benign
# 12585                 1                  0     Benign
# 12586                 1                  0     Benign
# 12587                 1                  0     Benign
# 12588                 1                  0     Benign
#
# [12589 rows x 29 columns]

# %%
def convert_url_base64_col_to_string(base64_string):
    try:
        decoded_string = base64.b64decode(base64_string['url_base64']).decode('utf8')
        return decoded_string
    except Exception as e:
        print("Invalid Encoding:    %s" %e, "\n\nPlease provide base64 encoded string")

# %%
X_df2['url_base64'] = X_df2.apply(convert_url_base64_col_to_string,axis=1)

# %%
X_df2.loc[X_df2['verdict'] == 'Malicious']
# Out:
#                                               url_base64  \
# 31                    http://apolo-ro.servidorturbo.net/
# 137    http://www.thecentersite-downloadlinknew.icu/?...
# 144    https://freshvegi.in/views/opp/365voice/login/...
# 163                 http://myetherwallett.neocities.org/
# 224                      http://generalservicesteam.com/
# 239                              http://standardscs.com/
# 257    http://ppsubscriptionreview9edan6nlb.aovmean.com/
# 281                  https://myiphone-support-apple.com/
# 287          http://ppreview-webscr7b5mgb0hb.cnaova.com/
# 331    http://nongkung.com/components/log/secured-dri...
# 351    http://sbfurniture-bd.com/wp-content/En_us/Cli...
# 352          http://ppreview-webscr80l164d6d.cnaova.com/
# 376    http://mumtazahmed.com/._@_@/.@@@/cmd-login=61...
# 382                             http://dontlitigate.com/
# 392    http://www.niaa.org.au/sites/En/Invoice-Correc...
# 444    http://beyond100.com.au/0027/777/new%20outlook...
# 479                             http://stocklab.id/Vxh5/
# 516    http://dayahblang.id/ACH/PaymentInfo/Document/...
# 561    http://andreiarocha.com.br/default/US/Outstand...
# 571                           https://icloudtracker.com/
# 578                                    http://hagtex.no/
# 586                                 http://afgc.asso.fr/
# 640          http://ppreview-webscrgm349p2d4.cnaova.com/
# 671                             http://www.lmrental.com/
# 684                                 http://appielid.com/
# 686    http://44555.000webhostapp.com/4546/DropNewVas...
# 693                               http://berkanenow.com/
# 700                          http://stylestorylagos.com/
# 715                                http://cutt.us/S2gMU/
# 724    http://pos.rumen8.com/wp-content/cache/3292882...
# ...                                                  ...
# 11954                      http://livestatsnet.services/
# 11966                   http://moneyandthoughts.com/rll/
# 11989                http://www.afubiagroup.com/XQoB5mT/
# 11998                   http://winapphost.servehttp.com/
# 12009                            http://consultor100.es/
# 12070                              http://gtvtuning.com/
# 12071                          http://aziziriviera.info/
# 12096  http://hazelmatthys.com/auth/4e672f9869819adbb...
# 12105                              http://ryancurry.com/
# 12109        http://osteoliv.com/EN_US/Payments/2018-12/
# 12131                                 http://arbusi.net/
# 12177  http://agroconsultancy.ge/US/Clients_transacti...
# 12179    http://theshowzone.com/US/Transactions/2018-12/
# 12195  http://kingsunsh-com.gq/Emirates/emirates/emir...
# 12196                                http://lacadeau.in/
# 12238                           http://drcarrico.com.br/
# 12241  http://31.207.35.116/wordpress/invoices/364752...
# 12259  http://telebrationstudio.com/SP/Real/Real/2944...
# 12268                               https://bodelen.com/
# 12277  http://www.ebill.update.musthavetrades.com/log...
# 12309                           http://ppiijateng.or.id/
# 12327  http://cbacpartnership.org/verify/4e0e16ae0b4c...
# 12344          http://satfoliofiscal.com/deudapendiente/
# 12360                          http://securelink801.com/
# 12442              http://xn--slseriombudsmannen-h4b.no/
# 12455  https://comercialwmendes.com.br/chinw/English/...
# 12463            http://itqantrade.com/multimedia/konto/
# 12485  http://free.downloadrecipesearch.com/index.jht...
# 12517  http://www.microsoft.com-repair-windows.live/t...
# 12582                        http://plintakids.com/weFT/
#
#                                                url_title  \
# 31                                                   NaN
# 137                                Download Flash Player
# 144                                    Account Suspended
# 163                                    MyEtherWallet.com
# 224                              generalservicesteam.com
# 239                                Default Web Site Page
# 257            ppsubscriptionreview9edan6nlb.aovmean.com
# 281                                    Account Suspended
# 287                  ppreview-webscr7b5mgb0hb.cnaova.com
# 331                     One Drive Cloud Document Sharing
# 351                                    Account Suspended
# 352                  ppreview-webscr80l164d6d.cnaova.com
# 376                              Sign in to your account
# 382                                           Index of /
# 392                                                  NaN
# 444                                    Account Suspended
# 479                                                  NaN
# 516                                                  NaN
# 561                                    Account Suspended
# 571                                        iCloudTracker
# 578                                 Domene - Webhuset AS
# 586    Accueil - Association Francaise de Genie Civil...
# 640                  ppreview-webscrgm349p2d4.cnaova.com
# 671     Last Minute Rental – Just another WordPress site
# 684              appielid.com – このドメインはお名前.comで取得されています。
# 686                   Error 404 (Not Found) | 000webhost
# 693                                                 IIS7
# 700                                                  NaN
# 715                       Nothing found for Accessreport
# 724                                 Fap CEO | Nutaku.net
# ...                                                  ...
# 11954                                                NaN
# 11966                                    Contact Support
# 11989                                  Account Suspended
# 11998  Welcome to testeappserver.000webhostapp.com Fr...
# 12009                                                NaN
# 12070                                       Opolska39.pl
# 12071                                  Account Suspended
# 12096  Skating Store Online Synchronized Skating Dres...
# 12105   Página não encontrada – Conci – Consultoria Lda.
# 12109                                  Account Suspended
# 12131  arbusi.net - This website is for sale! - arbus...
# 12177                               მთავარი - ProServ.Ge
# 12179                                                NaN
# 12195                                    Contact Support
# 12196                                         Index of /
# 12238  Dr. Carriço | Site do médico cirurgião e espec...
# 12241                                                NaN
# 12259                                            Dropbox
# 12268                                             Google
# 12277                  my email - Etisalat Internet Mail
# 12309  PPII Korwil Jateng – Perkumpulan Pendidik IPA ...
# 12327                      Log in to your ΡayΡal account
# 12344                                  Account Suspended
# 12360                                                NaN
# 12442                                         Index of /
# 12455                                 A | Email Settings
# 12463  Cembra Money Bank eService - Aktivieren Sie Ih...
# 12485                                       RecipeSearch
# 12517  Get more speed, malware free, registry Clean P...
# 12582                                     Index of /weFT
#
#                                             url_favicons  url_is_html  \
# 31                                                   NaN         True
# 137                                                  NaN         True
# 144                                                  NaN         True
# 163    d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 224                                                  NaN         True
# 239                                                  NaN         True
# 257                                                  NaN         True
# 281                                                  NaN         True
# 287                                                  NaN         True
# 331                                                  NaN         True
# 351                                                  NaN         True
# 352                                                  NaN         True
# 376                     3312f67413a1d8f466387e6bd3ae2845         True
# 382                                                  NaN         True
# 392                                                  NaN         True
# 444                                                  NaN         True
# 479                                                  NaN         True
# 516                                                  NaN         True
# 561                                                  NaN         True
# 571                                                  NaN         True
# 578    94a345780dbc75a0bbc26abfa0de0ee7,94a345780dbc7...         True
# 586    d41d8cd98f00b204e9800998ecf8427e,5b379b396b464...         True
# 640                                                  NaN         True
# 671                                                  NaN         True
# 684                                                  NaN         True
# 686                     9d70d990362f0629658691cc29e6cf8a         True
# 693                                                  NaN         True
# 700                                                  NaN         True
# 715    d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 724                     85b35843979a3f6c4b6a4c9458caa12f         True
# ...                                                  ...          ...
# 11954                                                NaN         True
# 11966                                                NaN         True
# 11989                                                NaN         True
# 11998                                                NaN         True
# 12009                                                NaN         True
# 12070                                                NaN         True
# 12071                                                NaN         True
# 12096  d41d8cd98f00b204e9800998ecf8427e,d41d8cd98f00b...         True
# 12105  d41d8cd98f00b204e9800998ecf8427e,9e68eaefee365...         True
# 12109                                                NaN         True
# 12131                                                NaN         True
# 12177                   d41d8cd98f00b204e9800998ecf8427e         True
# 12179                                                NaN         True
# 12195                                                NaN         True
# 12196                                                NaN         True
# 12238                                                NaN         True
# 12241                                                NaN         True
# 12259                   c47d35f5f0304f4d671add9375865167         True
# 12268                                                NaN         True
# 12277                   d41d8cd98f00b204e9800998ecf8427e         True
# 12309  d41d8cd98f00b204e9800998ecf8427e,76e06e98b4fce...         True
# 12327                   e887421f1f2c62831c0de41e5771a58f         True
# 12344                                                NaN         True
# 12360                                                NaN         True
# 12442                                                NaN         True
# 12455                                                NaN         True
# 12463                                                NaN         True
# 12485                                                NaN         True
# 12517                   d41d8cd98f00b204e9800998ecf8427e         True
# 12582                                                NaN         True
#
#                              url_content_type  url_total_favicon  \
# 31                   text/html; charset=UTF-8                  0
# 137                  text/html; charset=UTF-8                  0
# 144                                 text/html                  0
# 163                                 text/html                  5
# 224                  text/html; charset=utf-8                  0
# 239                                 text/html                  0
# 257                  text/html; charset=UTF-8                  0
# 281                                 text/html                  0
# 287                  text/html; charset=UTF-8                  0
# 331                  text/html; charset=UTF-8                  0
# 351                                 text/html                  0
# 352                  text/html; charset=UTF-8                  0
# 376                                 text/html                  1
# 382              text/html;charset=ISO-8859-1                  0
# 392                  text/html; charset=UTF-8                  0
# 444                                 text/html                  0
# 479                  text/html; charset=UTF-8                  0
# 516                  text/html; charset=UTF-8                  0
# 561                                 text/html                  0
# 571                  text/html; charset=UTF-8                  0
# 578                  text/html; charset=utf-8                  2
# 586                  text/html; charset=utf-8                  2
# 640                  text/html; charset=UTF-8                  0
# 671                  text/html; charset=UTF-8                  0
# 684                  text/html; charset=UTF-8                  0
# 686                  text/html; charset=UTF-8                  1
# 693                                 text/html                  0
# 700                  text/html; charset=UTF-8                  0
# 715    text/html; Charset=UTF-8;charset=UTF-8                  3
# 724                  text/html; charset=UTF-8                  1
# ...                                       ...                ...
# 11954                text/html; charset=utf-8                  0
# 11966                               text/html                  0
# 11989                               text/html                  0
# 11998                text/html; charset=UTF-8                  0
# 12009                 text/html;charset=utf-8                  0
# 12070                               text/html                  0
# 12071                               text/html                  0
# 12096                text/html; charset=UTF-8                  2
# 12105                text/html; charset=UTF-8                  3
# 12109                               text/html                  0
# 12131                               text/html                  0
# 12177                               text/html                  1
# 12179                text/html; charset=UTF-8                  0
# 12195                               text/html                  0
# 12196            text/html;charset=ISO-8859-1                  0
# 12238                text/html; charset=UTF-8                  0
# 12241                text/html; charset=UTF-8                  0
# 12259                               text/html                  1
# 12268                               text/html                  0
# 12277                               text/html                  1
# 12309                text/html; charset=UTF-8                  3
# 12327                text/html; charset=UTF-8                  1
# 12344                               text/html                  0
# 12360                text/html; charset=UTF-8                  0
# 12442                text/html; charset=utf-8                  0
# 12455                               text/html                  0
# 12463                               text/html                  0
# 12485                 text/html;charset=UTF-8                  0
# 12517                text/html; charset=utf-8                  1
# 12582            text/html;charset=ISO-8859-1                  0
#
#                                           url_og_domains  \
# 31                                                   NaN
# 137                     e64b58dfdcb522200f84132dfa49636d
# 144                     5f395d3a47e44537ade5365501edc4d1
# 163    7b43cc2c2fcc3917dc1379e557037f83,93133afdf9fcd...
# 224                     038cbf6c65c623d3d46859785c126dd8
# 239    5011a6649e9184261d82542142c5fadc,5f395d3a47e44...
# 257                                                  NaN
# 281                     5f395d3a47e44537ade5365501edc4d1
# 287                                                  NaN
# 331                                                  NaN
# 351                     5f395d3a47e44537ade5365501edc4d1
# 352                                                  NaN
# 376    4bb8a59adaa41ac96ae72703f1cb0e0c,b0d6f55dc0310...
# 382                     076916cba364ee90b38b6af4a4b09955
# 392                                                  NaN
# 444                     5f395d3a47e44537ade5365501edc4d1
# 479                                                  NaN
# 516                                                  NaN
# 561                     5f395d3a47e44537ade5365501edc4d1
# 571                     0bc941f169e3aa2eb4e0ca03206fe396
# 578    4fd9c9a2de4fbab8494b2f27d37f3118,114c4d12519de...
# 586    eced6b3200e96cad6478b1bfba7cb999,693bb6289543b...
# 640                                                  NaN
# 671    bcbafb69b52516b1733a52b737d2d4b7,4fd9c9a2de4fb...
# 684                     46bf2518217fb55ef48a3dabdae62ab2
# 686                     a64fa63a9f962949675d90c7f0ddf097
# 693                     81f21d97d4c70f4ea1f9459616c980ba
# 700                                                  NaN
# 715    4fd9c9a2de4fbab8494b2f27d37f3118,7207dff096dcb...
# 724                     4b8f94f2e5f50cdfece992964a898bbf
# ...                                                  ...
# 11954                                                NaN
# 11966                                                NaN
# 11989                                                NaN
# 11998  4fd9c9a2de4fbab8494b2f27d37f3118,e203e98e4c606...
# 12009                                                NaN
# 12070                                                NaN
# 12071                   5f395d3a47e44537ade5365501edc4d1
# 12096  e203e98e4c606735cf56db84a002fd22,5f395d3a47e44...
# 12105                   2ee93cae86745085b4bbe91d699023c8
# 12109                   5f395d3a47e44537ade5365501edc4d1
# 12131  ba3be808ebe1435c3d7bd9a191f033e1,ed12fe971754f...
# 12177                                                NaN
# 12179                                                NaN
# 12195                                                NaN
# 12196                   f821ae15e6eae72e72ae08adc72dcd93
# 12238  4fd9c9a2de4fbab8494b2f27d37f3118,e203e98e4c606...
# 12241                                                NaN
# 12259  fade33eb36e4c140cd291f19ced78507,d41d8cd98f00b...
# 12268  e0b106fd149f84e5156335d2d9c0d3cb,ff31304115d63...
# 12277                                                NaN
# 12309  569103fd51ed06f48992d2bdbc267b3c,5f395d3a47e44...
# 12327                   d327dcffd0f88ea88cc09caaece94ddb
# 12344                                                NaN
# 12360                                                NaN
# 12442                   fd3d3673fe653044c5f6a0c1bae710ff
# 12455                                                NaN
# 12463                   24d30d09182753e36647050ac8f9d221
# 12485  45911bf944cfcab2bc935596e92ae91a,41c1c9b28fc5b...
# 12517  24e321e968e59b99a875ec20a4387c61,62814f4151b1d...
# 12582                   868bac9ba1f6721712315a1b62d5bf58
#
#        url_total_og_domains  url_total_og_links       url_file_type  \
# 31                        0                   0       inode/x-empty
# 137                       1                   8           text/html
# 144                       1                   1           text/html
# 163                      23                 150           text/html
# 224                       1                   3           text/html
# 239                       3                   3           text/html
# 257                       0                   0           text/html
# 281                       1                   1           text/html
# 287                       0                   0           text/html
# 331                       0                   0           text/html
# 351                       1                   1           text/html
# 352                       0                   0           text/html
# 376                       4                   4           text/html
# 382                       1                  19           text/html
# 392                       0                   0  application/msword
# 444                       1                   1           text/html
# 479                       0                   0  application/msword
# 516                       0                   0  application/msword
# 561                       1                   1           text/html
# 571                       1                   2           text/html
# 578                       8                  46           text/html
# 586                       5                 186           text/html
# 640                       0                   0           text/html
# 671                      13                  38           text/html
# 684                       1                   2           text/html
# 686                       1                   2           text/html
# 693                       1                   1           text/html
# 700                       0                   0          text/plain
# 715                       5                  31           text/html
# 724                       1                   4  application/msword
# ...                     ...                 ...                 ...
# 11954                     0                   0           text/html
# 11966                     0                   0           text/html
# 11989                     0                   0           text/html
# 11998                     4                  18           text/html
# 12009                     0                   0       inode/x-empty
# 12070                     0                   0           text/html
# 12071                     1                   1           text/html
# 12096                     9                  38           text/html
# 12105                     1                  33           text/html
# 12109                     1                   1           text/html
# 12131                     3                   4           text/html
# 12177                     0                   0           text/html
# 12179                     0                   0  application/msword
# 12195                     0                   0           text/html
# 12196                     1                  18           text/html
# 12238                     7                  34           text/html
# 12241                     0                   0  application/msword
# 12259                     2                   6           text/html
# 12268                    21                  42           text/html
# 12277                     0                   0           text/html
# 12309                     4                  39           text/html
# 12327                     1                   5           text/html
# 12344                     0                   0           text/html
# 12360                     0                   0       inode/x-empty
# 12442                     1                   6           text/html
# 12455                     0                   0           text/html
# 12463                     1                   4           text/html
# 12485                     2                   3           text/html
# 12517                     9                  23           text/html
# 12582                     1                   3           text/html
#
#          ...     domain_file_type  \
# 31       ...        inode/x-empty
# 137      ...        inode/x-empty
# 144      ...            text/html
# 163      ...            text/html
# 224      ...            text/html
# 239      ...            text/html
# 257      ...            text/html
# 281      ...            text/html
# 287      ...            text/html
# 331      ...      application/xml
# 351      ...            text/html
# 352      ...            text/html
# 376      ...            text/html
# 382      ...            text/html
# 392      ...            text/html
# 444      ...            text/html
# 479      ...            text/html
# 516      ...            text/html
# 561      ...            text/html
# 571      ...            text/html
# 578      ...            text/html
# 586      ...            text/html
# 640      ...            text/html
# 671      ...            text/html
# 684      ...            text/html
# 686      ...            text/html
# 693      ...            text/html
# 700      ...           text/plain
# 715      ...            text/html
# 724      ...            text/html
# ...      ...                  ...
# 11954    ...            text/html
# 11966    ...            text/html
# 11989    ...            text/html
# 11998    ...            text/html
# 12009    ...        inode/x-empty
# 12070    ...            text/html
# 12071    ...            text/html
# 12096    ...            text/html
# 12105    ...            text/html
# 12109    ...            text/html
# 12131    ...            text/html
# 12177    ...            text/html
# 12179    ...            text/html
# 12195    ...            text/html
# 12196    ...            text/html
# 12238    ...            text/html
# 12241    ...            text/html
# 12259    ...                   -1
# 12268    ...            text/html
# 12277    ...            text/html
# 12309    ...            text/html
# 12327    ...            text/html
# 12344    ...            text/html
# 12360    ...        inode/x-empty
# 12442    ...            text/html
# 12455    ...            text/html
# 12463    ...            text/html
# 12485    ...            text/html
# 12517    ...                   -1
# 12582    ...            text/html
#
#                                       landing_url_base64 title_match  \
# 31      aHR0cDovL2Fwb2xvLXJvLnNlcnZpZG9ydHVyYm8ubmV0Lw==        True
# 137    aHR0cHM6Ly9zYWZlLmJlc3RjZW50ZXJ0b2NvbnRlbnQueH...       False
# 144    aHR0cHM6Ly9mcmVzaHZlZ2kuaW4vY2dpLXN5cy9zdXNwZW...        True
# 163    aHR0cHM6Ly9teWV0aGVyd2FsbGV0dC5uZW9jaXRpZXMub3...        True
# 224    aHR0cDovL2dlbmVyYWxzZXJ2aWNlc3RlYW0uY29tLz9yZX...        True
# 239    aHR0cDovL3N0YW5kYXJkc2NzLmNvbS9jZ2ktc3lzL2RlZm...        True
# 257    aHR0cDovL3Bwc3Vic2NyaXB0aW9ucmV2aWV3OWVkYW42bm...        True
# 281    aHR0cHM6Ly9teWlwaG9uZS1zdXBwb3J0LWFwcGxlLmNvbS...        True
# 287    aHR0cDovL3BwcmV2aWV3LXdlYnNjcjdiNW1nYjBoYi5jbm...        True
# 331    aHR0cDovL25vbmdrdW5nLmNvbS9jb21wb25lbnRzL2xvZy...       False
# 351    aHR0cDovL3NiZnVybml0dXJlLWJkLmNvbS9jZ2ktc3lzL3...        True
# 352    aHR0cDovL3BwcmV2aWV3LXdlYnNjcjgwbDE2NGQ2ZC5jbm...        True
# 376    aHR0cDovL211bXRhemFobWVkLmNvbS8uX0BfQC8uQEBAL2...       False
# 382                     aHR0cDovL2RvbnRsaXRpZ2F0ZS5jb20v        True
# 392                                             ZGF0YTos       False
# 444    aHR0cDovL2JleW9uZDEwMC5jb20uYXUvY2dpLXN5cy9zdX...        True
# 479                                             ZGF0YTos       False
# 516                                             ZGF0YTos       False
# 561    aHR0cDovL2FuZHJlaWFyb2NoYS5jb20uYnIvY2dpLXN5cy...        True
# 571                 aHR0cHM6Ly9pY2xvdWR0cmFja2VyLmNvbS8=        True
# 578    aHR0cHM6Ly93d3cud2ViaHVzZXQubm8vdGplbmVzdGVyL2...        True
# 586                         aHR0cDovL2FmZ2MuYXNzby5mci8=        True
# 640    aHR0cDovL3BwcmV2aWV3LXdlYnNjcmdtMzQ5cDJkNC5jbm...        True
# 671                         aHR0cHM6Ly9sbXJlbnRhbC5jb20v        True
# 684                         aHR0cDovL2FwcGllbGlkLmNvbS8=        True
# 686    aHR0cDovLzQ0NTU1LjAwMHdlYmhvc3RhcHAuY29tLzQ1ND...       False
# 693                     aHR0cDovL2JlcmthbmVub3cuY29tLw==        True
# 700                 aHR0cDovL3N0eWxlc3RvcnlsYWdvcy5jb20v        True
# 715    aHR0cHM6Ly93d3cudGhlbWVob3V6LmNvbS9hY2Nlc3NyZX...       False
# 724    aHR0cHM6Ly93d3cuZWNwbXMubmV0L2NwNDFmMGNpP2tleT...       False
# ...                                                  ...         ...
# 11954           aHR0cDovL2xpdmVzdGF0c25ldC5zZXJ2aWNlcy8=        True
# 11966  aHR0cDovL21vbmV5YW5kdGhvdWdodHMuY29tL2NnaS1zeX...        True
# 11989  aHR0cDovL3d3dy5hZnViaWFncm91cC5jb20vY2dpLXN5cy...        True
# 11998  aHR0cDovL3Rlc3RlYXBwc2VydmVyLjAwMHdlYmhvc3RhcH...        True
# 12009                   aHR0cDovL2NvbnN1bHRvcjEwMC5lcy8=        True
# 12070                       aHR0cDovL2d0dnR1bmluZy5jb20v        True
# 12071  aHR0cDovL2F6aXppcml2aWVyYS5pbmZvL2NnaS1zeXMvc3...        True
# 12096               aHR0cHM6Ly9oYXplbG1hdHRoeXMuY29tLw==        True
# 12105               aHR0cDovL3d3dy5jb25jaS5wdC9tdW11bmk=        True
# 12109  aHR0cDovL29zdGVvbGl2LmNvbS9jZ2ktc3lzL3N1c3Blbm...        True
# 12131  aHR0cDovL3d3MS5hcmJ1c2kubmV0Lz9zdWIxPTgzYTY2ZT...        True
# 12177  aHR0cDovL2Fncm9jb25zdWx0YW5jeS5nZS9jZ2ktc3lzL3...        True
# 12179                                           ZGF0YTos       False
# 12195  aHR0cDovL2tpbmdzdW5zaC1jb20uZ3EvY2dpLXN5cy9zdX...        True
# 12196                       aHR0cDovL2xhY2FkZWF1LmluLw==        True
# 12238                   aHR0cDovL2RyY2Fycmljby5jb20uYnIv        True
# 12241                                           ZGF0YTos       False
# 12259  aHR0cDovL3RlbGVicmF0aW9uc3R1ZGlvLmNvbS9TUC9SZW...       False
# 12268   aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8/Z3dzX3JkPXNzbA==        True
# 12277  aHR0cDovL3d3dy5lYmlsbC51cGRhdGUubXVzdGhhdmV0cm...        True
# 12309                   aHR0cDovL3BwaWlqYXRlbmcub3IuaWQv        True
# 12327  aHR0cDovL2NiYWNwYXJ0bmVyc2hpcC5vcmcvdmVyaWZ5Lz...       False
# 12344  aHR0cDovL3NhdGZvbGlvZmlzY2FsLmNvbS9jZ2ktc3lzL3...        True
# 12360               aHR0cDovL3NlY3VyZWxpbms4MDEuY29tLw==        True
# 12442  aHR0cDovL3huLS1zbHNlcmlvbWJ1ZHNtYW5uZW4taDRiLm...        True
# 12455  aHR0cHM6Ly9jb21lcmNpYWx3bWVuZGVzLmNvbS5ici9jaG...       False
# 12463  aHR0cDovL2l0cWFudHJhZGUuY29tL211bHRpbWVkaWEva2...       False
# 12485  aHR0cDovL2ZyZWUuZG93bmxvYWRyZWNpcGVzZWFyY2guY2...        True
# 12517  aHR0cHM6Ly9scC5wY3Rvbmljcy5jb20vZnhtcmt0Lz94LW...       False
# 12582               aHR0cDovL3BsaW50YWtpZHMuY29tL3dlRlQv       False
#
#        uri_length url_length  domain_entropy url_entropy  is_favicon_match  \
# 31              1         34        3.959094    3.959094                 1
# 137             1        132        4.062104    5.569830                 1
# 144            45         65        3.689704    4.135163                 1
# 163             1         36        3.951194    3.951194                 1
# 224             1         31        3.950344    3.950344                 1
# 239             1         23        3.642490    3.642490                 1
# 257             1         49        4.354007    4.354007                 1
# 281             1         35        3.992871    3.992871                 1
# 287             1         43        4.379298    4.379298                 1
# 331            39        225        3.546439    4.829523                 0
# 351            32         57        4.103910    4.446301                 1
# 352             1         43        4.565345    4.565345                 1
# 376            55         77        3.588354    4.828239                 0
# 382             1         24        3.736441    3.736441                 1
# 392            40         62        3.609668    4.441447                 1
# 444            38         61        4.053509    4.222855                 1
# 479             6         24        3.747413    3.970176                 1
# 516            51         71        3.653757    4.922713                 1
# 561            33         59        3.856196    4.471484                 1
# 571             1         26        3.997953    3.997953                 1
# 578             1         17        3.410417    3.410417                 1
# 586             1         20        3.584184    3.584184                 1
# 640             1         43        4.489877    4.489877                 1
# 671             1         24        3.740602    3.740602                 1
# 684             1         20        3.646439    3.646439                 1
# 686            51         81        3.929214    4.561908                 0
# 693             1         22        3.879664    3.879664                 1
# 700             1         27        3.782122    3.782122                 1
# 715             7         21        2.923231    3.535175                 0
# 724            80        101        3.788755    4.513078                 0
# ...           ...        ...             ...         ...               ...
# 11954           1         29        3.604032    3.604032                 1
# 11966           5         32        3.869331    4.015320                 1
# 11989           9         35        3.958229    4.286147                 1
# 11998           1         32        3.840018    3.840018                 1
# 12009           1         23        3.849224    3.849224                 1
# 12070           1         21        3.594466    3.594466                 1
# 12071           1         25        3.669275    3.669275                 1
# 12096         106        158        3.688722    5.550838                 1
# 12105           1         21        3.653757    3.653757                 1
# 12109          24         43        3.608695    4.536389                 1
# 12131           1         18        3.641604    3.641604                 1
# 12177          32         57        3.950064    4.391856                 1
# 12179          25         47        3.609668    4.367899                 1
# 12195          32         55        3.970176    4.064930                 1
# 12196           1         19        3.642150    3.642150                 1
# 12238           1         24        3.605389    3.605389                 1
# 12241          58         78        3.522572    4.877536                 1
# 12259          47         75        3.991794    4.621548                 0
# 12268           1         20        3.784184    3.784184                 1
# 12277          10        211        4.126862    4.766641                 1
# 12309           1         24        3.709148    3.709148                 1
# 12327         107        170        3.828238    5.393280                 0
# 12344          16         41        3.690260    4.015612                 1
# 12360           1         25        4.213661    4.213661                 1
# 12442           1         37        4.185824    4.185824                 1
# 12455          53         99        4.093139    4.579480                 1
# 12463          18         39        3.788755    3.948506                 0
# 12485          12         99        4.057313    4.944407                 1
# 12517           8         52        4.188982    4.217871                 0
# 12582           6         27        3.845351    4.134336                 0
#
#        total_at_the_rate    verdict
# 31                     0  Malicious
# 137                    0  Malicious
# 144                    0  Malicious
# 163                    0  Malicious
# 224                    0  Malicious
# 239                    0  Malicious
# 257                    0  Malicious
# 281                    0  Malicious
# 287                    0  Malicious
# 331                    0  Malicious
# 351                    0  Malicious
# 352                    0  Malicious
# 376                    5  Malicious
# 382                    0  Malicious
# 392                    0  Malicious
# 444                    0  Malicious
# 479                    0  Malicious
# 516                    0  Malicious
# 561                    0  Malicious
# 571                    0  Malicious
# 578                    0  Malicious
# 586                    0  Malicious
# 640                    0  Malicious
# 671                    0  Malicious
# 684                    0  Malicious
# 686                    0  Malicious
# 693                    0  Malicious
# 700                    0  Malicious
# 715                    0  Malicious
# 724                    0  Malicious
# ...                  ...        ...
# 11954                  0  Malicious
# 11966                  0  Malicious
# 11989                  0  Malicious
# 11998                  0  Malicious
# 12009                  0  Malicious
# 12070                  0  Malicious
# 12071                  0  Malicious
# 12096                  0  Malicious
# 12105                  0  Malicious
# 12109                  0  Malicious
# 12131                  0  Malicious
# 12177                  0  Malicious
# 12179                  0  Malicious
# 12195                  0  Malicious
# 12196                  0  Malicious
# 12238                  0  Malicious
# 12241                  0  Malicious
# 12259                  0  Malicious
# 12268                  0  Malicious
# 12277                  0  Malicious
# 12309                  0  Malicious
# 12327                  0  Malicious
# 12344                  0  Malicious
# 12360                  0  Malicious
# 12442                  0  Malicious
# 12455                  1  Malicious
# 12463                  0  Malicious
# 12485                  0  Malicious
# 12517                  0  Malicious
# 12582                  0  Malicious
#
# [470 rows x 29 columns]
